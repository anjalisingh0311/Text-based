# %%
import pandas as pd

# %%
df = pd.read_csv("/content/un-general-debates-blueprint.csv")

# %%
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# 15       25  1970     DZA                          Algeria
# 16       25  1970     ECU                          Ecuador
# 17       25  1970     FRA                           France
# 18       25  1970     GBR                   United Kingdom
# 19       25  1970     GHA                            Ghana
#
#                   speaker    position  \
# 0                 Mr. NAS         NaN
# 1      Mr. DE PABLO PARDO         NaN
# 2             Mr. McMAHON         NaN
# 3      Mr. KIRCHSCHLAEGER         NaN
# 4              Mr. HARMEL         NaN
# 5          Mr. GURINOVICH         NaN
# 6      Mr. CAMACHO OMISTE         NaN
# 7      Mr. GIBSON BARBOZA         NaN
# 8               Mr. SHARP         NaN
# 9              Mr. AHIDJO  President
# 10            Mr. ICKONGA         NaN
# 11  Mr. VASQUEZ CARRIZOSA         NaN
# 12              Mr. FACIO         NaN
# 13            Mr. ALARCON         NaN
# 14        Mr FERNANDEZ G.
# 15              Mr. YAZID         NaN
# 16            Mr. Benites         NaN
# 17           Mr. SCHUMANN         NaN
# 18   Sir Alec DOUGLASHOME         NaN
# 19              Mr. OWUSU         NaN
#
#                                                  text
# 0   33: May I first convey to our President the co...
# 1   177.\t : It is a fortunate coincidence that pr...
# 2   100.\t  It is a pleasure for me to extend to y...
# 3   155.\t  May I begin by expressing to Ambassado...
# 4   176. No doubt each of us, before coming up to ...
# 5   \n71.\t. We are today mourning the untimely de...
# 6   135.\t  I wish to congratulate the President o...
# 7   1.\tMr. President, I should like, first of all...
# 8   \nThe General Assembly is fortunate indeed to ...
# 9   : A year ago I came here as the Acting Preside...
# 10  122.\t  I cannot begin my intervention without...
# 11  Mr. President, this visit to the United Nation...
# 12  62.\t  Mr. President, your election to the Pre...
# 13  1.\t  Mr. President, I should first like to co...
# 14  \n\n\n Mr. President, it was a source of great...
# 15  1.  The delegation of Algeria is very pleased ...
# 16  71.  It had been my hope that a loftier person...
# 17  84.\t  Within one month, when we celebrate the...
# 18  110.\t Mr. President, I should like first to s...
# 19  121.\t I should like to begin by congratulatin...

# %%
df
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            Mr. NAS
# 1          25  1970     ARG     Argentina                 Mr. DE PABLO PARDO
# 2          25  1970     AUS     Australia                        Mr. McMAHON
# 3          25  1970     AUT       Austria                 Mr. KIRCHSCHLAEGER
# 4          25  1970     BEL       Belgium                         Mr. HARMEL
# ...       ...   ...     ...           ...                                ...
# 7073       70  2015     YEM         Yemen  Mr. Abdrabuh Mansour Hadi Mansour
# 7074       70  2015     YUG    Yugoslavia               Mr. Tomislav Nikolić
# 7075       70  2015     ZAF  South Africa                         Jacob Zuma
# 7076       70  2015     ZMB        Zambia             Mr. Edgar Chagwa Lungu
# 7077       70  2015     ZWE      Zimbabwe                      Robert Mugabe
#
#        position                                               text
# 0           NaN  33: May I first convey to our President the co...
# 1           NaN  177.\t : It is a fortunate coincidence that pr...
# 2           NaN  100.\t  It is a pleasure for me to extend to y...
# 3           NaN  155.\t  May I begin by expressing to Ambassado...
# 4           NaN  176. No doubt each of us, before coming up to ...
# ...         ...                                                ...
# 7073  President  On behalf of the people and the Government of ...
# 7074  President  \nSeventy years have passed since the establis...
# 7075  President  I should like to congratulate the President an...
# 7076  President  I would like to begin by thanking the Secretar...
# 7077  President  Allow me at the outset to extend to Mr. Mogens...
#
# [7078 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %%
df
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            Mr. NAS
# 1          25  1970     ARG     Argentina                 Mr. DE PABLO PARDO
# 2          25  1970     AUS     Australia                        Mr. McMAHON
# 3          25  1970     AUT       Austria                 Mr. KIRCHSCHLAEGER
# 4          25  1970     BEL       Belgium                         Mr. HARMEL
# ...       ...   ...     ...           ...                                ...
# 7073       70  2015     YEM         Yemen  Mr. Abdrabuh Mansour Hadi Mansour
# 7074       70  2015     YUG    Yugoslavia               Mr. Tomislav Nikolić
# 7075       70  2015     ZAF  South Africa                         Jacob Zuma
# 7076       70  2015     ZMB        Zambia             Mr. Edgar Chagwa Lungu
# 7077       70  2015     ZWE      Zimbabwe                      Robert Mugabe
#
#        position                                               text
# 0           NaN  33: May I first convey to our President the co...
# 1           NaN  177.\t : It is a fortunate coincidence that pr...
# 2           NaN  100.\t  It is a pleasure for me to extend to y...
# 3           NaN  155.\t  May I begin by expressing to Ambassado...
# 4           NaN  176. No doubt each of us, before coming up to ...
# ...         ...                                                ...
# 7073  President  On behalf of the people and the Government of ...
# 7074  President  \nSeventy years have passed since the establis...
# 7075  President  I should like to congratulate the President an...
# 7076  President  I would like to begin by thanking the Secretar...
# 7077  President  Allow me at the outset to extend to Mr. Mogens...
#
# [7078 rows x 7 columns]

# %%
df.dtypes
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %%
df
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            Mr. NAS
# 1          25  1970     ARG     Argentina                 Mr. DE PABLO PARDO
# 2          25  1970     AUS     Australia                        Mr. McMAHON
# 3          25  1970     AUT       Austria                 Mr. KIRCHSCHLAEGER
# 4          25  1970     BEL       Belgium                         Mr. HARMEL
# ...       ...   ...     ...           ...                                ...
# 7073       70  2015     YEM         Yemen  Mr. Abdrabuh Mansour Hadi Mansour
# 7074       70  2015     YUG    Yugoslavia               Mr. Tomislav Nikolić
# 7075       70  2015     ZAF  South Africa                         Jacob Zuma
# 7076       70  2015     ZMB        Zambia             Mr. Edgar Chagwa Lungu
# 7077       70  2015     ZWE      Zimbabwe                      Robert Mugabe
#
#        position                                               text
# 0           NaN  33: May I first convey to our President the co...
# 1           NaN  177.\t : It is a fortunate coincidence that pr...
# 2           NaN  100.\t  It is a pleasure for me to extend to y...
# 3           NaN  155.\t  May I begin by expressing to Ambassado...
# 4           NaN  176. No doubt each of us, before coming up to ...
# ...         ...                                                ...
# 7073  President  On behalf of the people and the Government of ...
# 7074  President  \nSeventy years have passed since the establis...
# 7075  President  I should like to congratulate the President an...
# 7076  President  I would like to begin by thanking the Secretar...
# 7077  President  Allow me at the outset to extend to Mr. Mogens...
#
# [7078 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7078 entries, 0 to 7077
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7078 non-null   int64
#  1   year          7078 non-null   int64
#  2   country       7078 non-null   object
#  3   country_name  7078 non-null   object
#  4   speaker       7052 non-null   object
#  5   position      4484 non-null   object
#  6   text          7078 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 387.2+ KB

# %%
df.describe()
# Out:
#            session         year
# count  7078.000000  7078.000000
# mean     50.873834  1995.873834
# std      12.177856    12.177856
# min      25.000000  1970.000000
# 25%      41.000000  1986.000000
# 50%      52.000000  1997.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %%
df['length'] = df['text'].str.len()

# %%
df.describe()
# Out:
#            session         year        length
# count  7078.000000  7078.000000   7078.000000
# mean     50.873834  1995.873834  17577.599604
# std      12.177856    12.177856   7629.659164
# min      25.000000  1970.000000   2805.000000
# 25%      41.000000  1986.000000  11885.250000
# 50%      52.000000  1997.000000  16007.500000
# 75%      61.000000  2006.000000  21903.250000
# max      70.000000  2015.000000  72041.000000

# %%
df.describe(include='O')
# Out:
#        country country_name        speaker                      position  \
# count     7078         7078           7052                          4484
# unique     199          199           5094                           106
# top        ALB      Albania  Seyoum Mesfin  Minister for Foreign Affairs
# freq        43           43             12                          1813
#
#                                                      text
# count                                                7078
# unique                                               7078
# top     33: May I first convey to our President the co...
# freq                                                    1

# %%
df['speaker'].fillna('unknown', inplace=True)
df['position'].fillna('unknown', inplace=True)

# %%
df.isna().sum()
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %%
df['speaker'] = df['speaker'].str.upper()
df['position'] = df['position'].str.upper()

# %%
df['text'] = df['text'].str.upper()

# %%
df[df['speaker'].str.contains('BUSH')]
# Out:
#       session  year country   country_name             speaker   position  \
# 2291       44  1989     USA  United States                BUSH  PRESIDENT
# 2447       45  1990     USA  United States         GEORGE BUSH    UNKNOWN
# 2609       46  1991     USA  United States         GEORGE BUSH  PRESIDENT
# 2778       47  1992     USA  United States     MR. GEORGE BUSH  PRESIDENT
# 4385       56  2001     USA  United States      GEORGE W. BUSH  PRESIDENT
# 4573       57  2002     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 4762       58  2003     USA  United States      GEORGE W. BUSH  PRESIDENT
# 4953       59  2004     USA  United States   MR. GEORGE W BUSH  PRESIDENT
# 5331       61  2006     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5522       62  2007     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5714       63  2008     USA  United States      GEORGE W. BUSH  PRESIDENT
#
#                                                    text  length
# 2291  ﻿I AM HONOURED TO ADDRESS THE GENERAL ASSEMBLY...   19779
# 2447  ﻿\nIT IS REALLY A GREAT PRIVILEGE TO GREET YOU...   15843
# 2609  ﻿I AM HONOURED TO SPEAK WITH YOU AS YOU OPEN T...   15555
# 2778  FORTY-SEVEN YEARS AGO I WAS A YOUNG MAN OF 21,...   21105
# 4385  ﻿WE MEET IN A HALL DEVOTED TO\nPEACE; IN A CIT...   14724
# 4573  ﻿WE MEET ONE YEAR AND ONE DAY\nAFTER A TERRORI...   16684
# 4762  ﻿TWENTY-FOUR MONTHS AGO, AND\nYESTERDAY IN THE...   16962
# 4953  THANK YOU FOR THE HONOUR OF\nADDRESSING THE GE...   18628
# 5331  I AM GRATEFUL FOR THE PRIVILEGE OF \nSPEAKING ...   16675
# 5522  THANK YOU FOR THE OPPORTUNITY \nTO ADDRESS THE...   15483
# 5714  I AM PLEASED TO BE HERE TO \nADDRESS THE GENER...   18384

# %%
df['length'].plot()
# Out:
# <Axes: >

# %%
df['length'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %%
df['length'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns
where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
g = sns.catplot(data=df[where], x="country", y="length", kind='box')
g.fig.set_size_inches(10, 8)

# %%
import regex as re
def tokenize(text):
  return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)
